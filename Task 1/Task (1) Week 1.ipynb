# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/Tasks/Task 1'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Tasks/Task 1

# %%
df = pd.read_csv('Task 1/Task (1) Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df['Age_band_of_driver'].unique()
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object)

# %% [markdown]
# ### Handle Missing Values

# %%
df.count()
# Out:
# Time                           12316
# Day_of_week                    12316
# Age_band_of_driver             12316
# Sex_of_driver                  12316
# Educational_level              11575
# Vehicle_driver_relation        11737
# Driving_experience             11487
# Type_of_vehicle                11366
# Owner_of_vehicle               11834
# Service_year_of_vehicle         8388
# Defect_of_vehicle               7889
# Area_accident_occured          12077
# Lanes_or_Medians               11931
# Road_allignment                12174
# Types_of_Junction              11429
# Road_surface_type              12144
# Road_surface_conditions        12316
# Light_conditions               12316
# Weather_conditions             12316
# Type_of_collision              12161
# Number_of_vehicles_involved    12316
# Number_of_casualties           12316
# Vehicle_movement               12008
# Casualty_class                 12316
# Sex_of_casualty                12316
# ...

# %%
df['Type_of_vehicle'].isnull().sum()
# Out:
# 950

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['Age_band_of_driver'] == 'Unknown']
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 64     18:25:00      Monday            Unknown        Female
# 118     1:15:00    Saturday            Unknown        Female
# 155    15:20:00    Saturday            Unknown        Female
# 186    16:20:00      Friday            Unknown        Female
# 198    18:30:00      Monday            Unknown        Female
# ...         ...         ...                ...           ...
# 12216  13:57:00   Wednesday            Unknown          Male
# 12241   6:00:00      Sunday            Unknown          Male
# 12251  16:55:00      Friday            Unknown          Male
# 12252  16:55:00      Friday            Unknown          Male
# 12312  18:00:00      Sunday            Unknown          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 64     Junior high school                Employee             5-10yr
# 118    Junior high school                Employee         Above 10yr
# ...

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df['Cause_of_accident'].unique()
# Out:
# array(['Moving Backward', 'Overtaking', 'Changing lane to the left',
#        'Changing lane to the right', 'Overloading', 'Other',
#        'No priority to vehicle', 'No priority to pedestrian',
#        'No distancing', 'Getting off the vehicle improperly',
#        'Improper parking', 'Overspeed', 'Driving carelessly',
#        'Driving at high speed', 'Driving to the left', 'Unknown',
#        'Overturning', 'Turnover', 'Driving under the influence of drugs',
#        'Drunk driving'], dtype=object)

# %%
df['Fitness_of_casuality'].unique()
# Out:
# array([nan, 'Normal', 'Deaf', 'Other', 'Blind', 'NormalNormal'],
#       dtype=object)

# %%
df['Fitness_of_casuality'].isnull().sum()
# Out:
# 2635

# %%
df['Service_year_of_vehicle'].unique()
# Out:
# array(['Above 10yr', '5-10yrs', nan, '1-2yr', '2-5yrs', 'Unknown',
#        'Below 1yr'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# ...

# %%
df['Type_of_collision'].unique()
# Out:
# array(['Collision with roadside-parked vehicles',
#        'Vehicle with vehicle collision',
#        'Collision with roadside objects', 'Collision with animals',
#        'Other', 'Rollover', 'Fall from vehicles',
#        'Collision with pedestrians', 'With Train', 'Unknown', nan],
#       dtype=object)

# %%
df['Vehicle_movement'].unique()
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
df.drop(df[df['Vehicle_movement'].isnull()].index, inplace = True)

# %%
df.drop(df[df['Road_allignment'].isnull()].index, inplace = True)

# %%
df['Vehicle_driver_relation'].unique()
# Out:
# array(['Employee', 'Owner', 'Unknown', nan, 'Other'], dtype=object)

# %%
df['Vehicle_driver_relation'].isnull().sum()
# Out:
# 543

# %%
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])

# %%
df['Fitness_of_casuality'].head(10)
# Out:
# 0        NaN
# 1        NaN
# 3     Normal
# 4        NaN
# 7     Normal
# 8     Normal
# 9     Normal
# 10    Normal
# 11    Normal
# 12    Normal
# Name: Fitness_of_casuality, dtype: object

# %%
df.drop('Work_of_casuality', axis = 1, inplace=True)

# %%
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])

# %%
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode()[0])

# %%
df['Educational_level'].unique()
# Out:
# array(['Above high school', 'Junior high school', 'Elementary school',
#        nan, 'High school', 'Unknown', 'Illiterate', 'Writing & reading'],
#       dtype=object)

# %%
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0])

# %%
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0])

# %%
df['Lanes_or_Medians'].unique()
# Out:
# array([nan, 'Undivided Two way', 'other', 'Double carriageway (median)',
#        'One way', 'Two-way (divided with solid lines road marking)',
#        'Two-way (divided with broken lines road marking)', 'Unknown'],
#       dtype=object)

# %%
df['Owner_of_vehicle'].unique()
# Out:
# array(['Owner', 'Governmental', nan, 'Organization', 'Other'],
#       dtype=object)

# %%
df.drop(df[df['Area_accident_occured'].isnull()].index, inplace = True)

# %%
df.drop(df[df['Driving_experience'].isnull()].index, inplace = True)

# %%
df['Driving_experience'].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', 'No Licence',
#        'Below 1yr', nan, 'unknown'], dtype=object)

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', nan, 'Lorry (41?100Q)',
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %%
df['Types_of_Junction'] = df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])

# %%
df['Types_of_Junction'].unique()
# Out:
# array(['No junction', 'Y Shape', 'Crossing', 'O Shape', 'Other',
#        'Unknown', 'T Shape', 'X Shape', nan], dtype=object)

# %%
df['Type_of_vehicle'] = df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])

# %%
df.drop(df[df['Educational_level'].isnull()].index, inplace = True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Fitness_of_casuality           0
# Pedestrian_movement            0
# Cause_of_accident              0
# ...

# %%
df['Road_allignment'].unique().sum()
# Out:
# 'Tangent road with flat terrainTangent road with mild grade and flat terrainEscarpmentsTangent road with rolling terrainGentle horizontal curveTangent road with mountainous terrain andSteep grade downward with mountainous terrainSharp reverse curveSteep grade upward with mountainous terrain'

# %%
df.drop(df[df['Road_surface_type'].isnull()].index, inplace = True)

# %%
df.drop(df[df['Type_of_collision'].isnull()].index, inplace = True)

# %%
f = df[df['Service_year_of_vehicle'] == 'Unknown']
f.count()
f
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 10     14:40:00    Saturday              18-30          Male
# 43      9:12:00   Wednesday              18-30          Male
# 47     10:36:00      Friday              31-50          Male
# 64     18:25:00      Monday            Unknown        Female
# 74     11:02:00    Thursday              31-50          Male
# ...         ...         ...                ...           ...
# 12262  16:30:00     Tuesday              31-50          Male
# 12264  15:18:00      Monday              31-50          Male
# 12279  16:51:00   Wednesday              31-50          Male
# 12292  13:54:00    Saturday              31-50          Male
# 12303  12:48:00      Friday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 10      Above high school                   Owner              1-2yr
# 43     Junior high school                Employee         Above 10yr
# ...

# %%
df.drop('Service_year_of_vehicle', axis = 1, inplace=True)

# %%
df['Fitness_of_casuality'].unique()
# Out:
# array([nan, 'Normal', 'Deaf', 'Other', 'Blind', 'NormalNormal'],
#       dtype=object)

# %%
df['Fitness_of_casuality'].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 12311    False
# 12312    False
# 12313    False
# 12314    False
# 12315    False
# Name: Fitness_of_casuality, Length: 12316, dtype: bool

# %%
df['Work_of_casuality'].unique()
# Out:
# array([nan, 'Driver', 'Other', 'Unemployed', 'Employee', 'Self-employed',
#        'Student', 'Unknown'], dtype=object)

# %%
f = df[df['Work_of_casuality'] == 'Unknown']
f.count()
f
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 571    17:41:00      Monday              18-30          Male
# 889    10:35:00   Wednesday           Under 18          Male
# 1588   21:01:00     Tuesday              18-30          Male
# 1906   11:50:00     Tuesday              18-30          Male
# 3450   13:03:00      Friday              31-50          Male
# 3768   13:40:00      Sunday              31-50          Male
# 4467   16:47:00      Friday            Over 51          Male
# 5228   10:40:00      Monday              18-30          Male
# 5878   14:30:00      Monday            Over 51          Male
# 6196   19:20:00      Monday              18-30          Male
# 6895   17:46:00      Friday              31-50          Male
# 7579   15:14:00     Tuesday            Over 51          Male
# 7897   16:02:00   Wednesday           Under 18          Male
# 8596   17:20:00   Wednesday           Under 18          Male
# ...

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Fitness_of_casuality           0
# Pedestrian_movement            0
# Cause_of_accident              0
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.drop('Pedestrian_movement', axis = 1, inplace=True)

# %%
df['Pedestrian_movement'].unique()
# Out:
# array(['Not a Pedestrian', "Crossing from driver's nearside",
#        'Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle',
#        'Unknown or other',
#        'Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)',
#        'Walking along in carriageway, back to traffic',
#        'Walking along in carriageway, facing traffic',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle'],
#       dtype=object)

# %%
df['Road_allignment'].unique()
# Out:
# array(['Tangent road with mild grade and flat terrain',
#        'Tangent road with flat terrain', 'Escarpments',
#        'Tangent road with rolling terrain', 'Gentle horizontal curve',
#        'Tangent road with mountainous terrain and',
#        'Steep grade downward with mountainous terrain',
#        'Sharp reverse curve',
#        'Steep grade upward with mountainous terrain'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.drop('Defect_of_vehicle', axis = 1, inplace = True)

# %%
df.drop('Defect_of_vehicle', axis = 1, inplace = True)

# %%
df.drop[df[df[]]]

# %%
df[df['Service_year_of_vehicle'].isnull()]
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 5      14:15:00      Friday              31-50          Male
# 6      17:30:00   Wednesday              18-30          Male
# 11     14:40:00    Saturday              31-50          Male
# ...         ...         ...                ...           ...
# 12304   7:10:00      Friday              18-30          Male
# 12308  17:10:00      Friday              18-30          Male
# 12309   9:05:00      Friday              31-50        Female
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 2      Junior high school                Employee              1-2yr
# 3      Junior high school                Employee             5-10yr
# ...

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df = df.drop(df[df['Casualty_class'] == 'na'].index)
#اشيل الraws = na

# %%
df.head()
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 11  14:40:00    Saturday              31-50          Male   Above high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 3                 Employee             5-10yr  Public (> 45 seats)
# 8                 Employee         Above 10yr      Lorry (41?100Q)
# 9                 Employee              1-2yr           Automobile
# 11                Employee         No Licence           Automobile
# 14                Employee         Above 10yr           Automobile
#
#    Owner_of_vehicle Area_accident_occured  ... Number_of_casualties  \
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.head()
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 11  14:40:00    Saturday              31-50          Male   Above high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 3                 Employee             5-10yr  Public (> 45 seats)
# 8                 Employee         Above 10yr      Lorry (41?100Q)
# 9                 Employee              1-2yr           Automobile
# 11                Employee         No Licence           Automobile
# 14                Employee         Above 10yr           Automobile
#
#    Owner_of_vehicle Area_accident_occured  ... Number_of_vehicles_involved  \
# ...

# %%
df.Number_of_vehicles_involved = df.Number_of_vehicles_involved.astype(int)

# %%
df.Casualty_severity = df.Casualty_severity.astype(int)

# %%
df['Time'].unique()
# Out:
# array(['1:06:00', '17:20:00', '14:40:00', '17:45:00', '8:20:00',
#        '15:10:00', '12:11:00', '18:36:00', '18:10:00', '15:25:00',
#        '13:57:00', '20:30:00', '16:30:00', '21:50:00', '9:12:00',
#        '10:36:00', '18:19:00', '19:12:00', '11:38:00', '13:30:00',
#        '12:39:00', '18:25:00', '13:01:00', '13:45:00', '11:02:00',
#        '15:55:00', '20:00:00', '18:48:00', '23:25:00', '7:40:00',
#        '15:17:00', '9:45:00', '17:35:00', '20:50:00', '21:32:00',
#        '23:36:00', '17:54:00', '17:00:00', '1:15:00', '18:30:00',
#        '15:52:00', '12:33:00', '8:59:00', '17:25:00', '0:53:00',
#        '18:23:00', '5:24:00', '12:15:00', '6:35:00', '17:34:00',
#        '4:00:00', '15:50:00', '8:50:00', '0:25:00', '0:10:00', '15:20:00',
#        '1:05:00', '19:40:00', '19:08:00', '17:50:00', '21:30:00',
#        '14:49:00', '21:55:00', '7:30:00', '10:41:00', '13:16:00',
#        '11:30:00', '16:20:00', '20:40:00', '21:03:00', '18:17:00',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6660 entries, 3 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         6660 non-null   object
#  1   Day_of_week                  6660 non-null   object
#  2   Age_band_of_driver           6660 non-null   object
#  3   Sex_of_driver                6660 non-null   object
#  4   Educational_level            6660 non-null   object
#  5   Vehicle_driver_relation      6660 non-null   object
#  6   Driving_experience           6660 non-null   object
#  7   Type_of_vehicle              6660 non-null   object
#  8   Owner_of_vehicle             6660 non-null   object
#  9   Area_accident_occured        6660 non-null   object
#  10  Lanes_or_Medians             6660 non-null   object
#  11  Road_allignment              6660 non-null   object
#  12  Types_of_Junction            6660 non-null   object
# ...

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties  Casualty_severity
# count                  6660.000000           6660.000000        6660.000000
# mean                      2.036336              1.558408           2.898048
# std                       0.682214              1.019135           0.314293
# min                       1.000000              1.000000           1.000000
# 25%                       2.000000              1.000000           3.000000
# 50%                       2.000000              1.000000           3.000000
# 75%                       2.000000              2.000000           3.000000
# max                       7.000000              8.000000           3.000000

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df.plot.scatter(x='Number_of_casualties', y='Casualty_severity') #the outliers isn't removed!
# Out:
# <Axes: xlabel='Number_of_casualties', ylabel='Casualty_severity'>

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df['Sex_of_driver'].unique()
# Out:
# array(['Male', 'Unknown', 'Female'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6660 entries, 3 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         6660 non-null   object
#  1   Day_of_week                  6660 non-null   object
#  2   Age_band_of_driver           6660 non-null   object
#  3   Sex_of_driver                6660 non-null   object
#  4   Educational_level            6660 non-null   object
#  5   Vehicle_driver_relation      6660 non-null   object
#  6   Driving_experience           6660 non-null   object
#  7   Type_of_vehicle              6660 non-null   object
#  8   Owner_of_vehicle             6660 non-null   object
#  9   Area_accident_occured        6660 non-null   object
#  10  Lanes_or_Medians             6660 non-null   object
#  11  Road_allignment              6660 non-null   object
#  12  Types_of_Junction            6660 non-null   object
# ...

# %%
categorical_features = ['Day_of_week', 'Age_band_of_driver', 'Time', 'Sex_of_driver', 'Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty', 'Fitness_of_casuality', 'Cause_of_accident', 'Accident_severity']
for feature in categorical_features:
  plt.figure(figsize=(10, 6))
  df[feature].value_counts().plot(kind='bar')
  plt.title(f'Distribution of {feature}')
  plt.xlabel(feature)
  plt.ylabel('Count')
  plt.xticks(rotation=45, ha='right')
  plt.tight_layout()
  plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(x=df.Day_of_week,bins=20)
plt.xlabel('Day_of_week')
plt.show()

# %%
numerical_features = ['Number_of_vehicles_involved', 'Number_of_casualties', 'Casualty_severity']
for feature in numerical_features:
  plt.figure(figsize=(8,6))
  plt.hist(x=df[feature],bins=20)
  plt.title(f'Distribution of {feature}')
  plt.xlabel(feature)
  plt.show()

# %%
correlation_matrix = df[numerical_features].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(10, 6))
df[feature].value_counts().plot(kind='bar')
plt.title(f'Distribution of Age_band_of_driver')
plt.xlabel('Age_band_of_driver')
plt.ylabel('Type_of_vehicle')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df['Age_band_of_driver']
# Out:
# 0          18-30
# 1          31-50
# 2          18-30
# 3          18-30
# 4          18-30
#           ...
# 12311      31-50
# 12312    Unknown
# 12313    Over 51
# 12314      18-30
# 12315      18-30
# Name: Age_band_of_driver, Length: 12316, dtype: object

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
plt.figure(figsize=(10, 6))
df[feature].value_counts().plot(kind='bar')
plt.title(f'Distribution of Age_band_of_driver')
plt.xlabel('Age_band_of_driver')
plt.ylabel('Accident_severity')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
y = df['Age_band_of_driver'].value_counts()
labels = df['Age_band_of_driver'].unique()
y = df['Age_band_of_driver'].value_counts()
labels = df['Age_band_of_driver'].unique()
#.subset series
plt.pie(y, labels = labels)
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# *   Friday is the most frequent accidents on it
# *   From 18 - 30 and 31 - 50 is the most frequent accidents on it
# *   Males are the most frequent accidents on it
# *   Junior high school the most frequent accidents on it
# *   Employee relation the most frequent accidents on it
# *   Owner the most frequent accidents on it
# *   Alphabet roads, and dry in the daylight
# *   Number of vehicle involved 2
# *   Normal condition is the more common in accidents
